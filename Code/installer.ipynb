# %%
# !pip install -q gdown

# %%
import gdown

folder_link = "https://drive.google.com/drive/folders/1St-QmHBH7xCD20KaireevPNVcMmXVeBH"
output_folder = "data"

gdown.download_folder(folder_link, output=output_folder, quiet=False, use_cookies=False)
# Out:
# Retrieving folder contents
# Processing file 1EDFMyJ9_OwvsAeH1e0uqYRl8A5A6TQgq train-shitty.csv
# Processing file 16euSPrUYI5tLtQVAA5WIWfIo_aejstsB train.csv
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From (original): https://drive.google.com/uc?id=1EDFMyJ9_OwvsAeH1e0uqYRl8A5A6TQgq
# From (redirected): https://drive.google.com/uc?id=1EDFMyJ9_OwvsAeH1e0uqYRl8A5A6TQgq&confirm=t&uuid=86876430-343f-4e85-a2cf-4ed4815100d8
# To: /home/jovyan/data/train-shitty.csv
# 100%|██████████| 169M/169M [00:03<00:00, 45.5MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=16euSPrUYI5tLtQVAA5WIWfIo_aejstsB
# From (redirected): https://drive.google.com/uc?id=16euSPrUYI5tLtQVAA5WIWfIo_aejstsB&confirm=t&uuid=8030bd7f-8376-47ad-91ac-455c74eb7635
# To: /home/jovyan/data/train.csv
# 100%|██████████| 232M/232M [00:05<00:00, 42.0MB/s]
# Download completed
# ['data/train-shitty.csv', 'data/train.csv']
